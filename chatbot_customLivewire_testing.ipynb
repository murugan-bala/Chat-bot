# %% [markdown]
# ## My chatbot Demo
# ### Installations --Python 3.6
# 1. Rasa NLU
# 2. Rasa Core (pip install rasa-core)
# 3. SpaCy Language Model

# %%
import logging, io, json, warnings
logging.basicConfig(level="INFO")
warnings.filterwarnings('ignore')

import rasa_nlu
import rasa_core
import spacy

print("rasa_nlu: {} rasa_core: {}".format(rasa_nlu.__version__, rasa_core.__version__))
print("Loading spaCy language model...")
print(spacy.load("en")("Hello world!"))
# Out:
# rasa_nlu: 0.15.1 rasa_core: 0.14.5
# Loading spaCy language model...
# Hello world!

# %% [markdown]
# ## 1. Teaching the bot to understand user inputs using Rasa NLU
# ### Preparing the NLU Training Data

# %%
nlu_md = """
## intent:greet
- hey
- hello there
- hi
- hello there
- good morning
- good evening
- hi chatbot
- hey there
- let's go
- hey dude
- goodmorning
- goodevening
- good afternoon

## intent:LIVEWIRE
- livewire
- livewire
- what is livewire
- define livewire
- context of livewire
- could you please give what do you meant livewire
- content of livewire 
- what do you meant livewire?
- say something about livewire
- about livewire
- brief about livewire 

## intent:Course_Launch_Issue
- I am unable to launch the course
- Error in the assessment launch
- error in the assessment launch
- Issue while taking the assessment
- Issue with the reference material mapping in Curriculum
- Gentle reminder -Get Enabled, Get Certified || NOC Services
- Gentle reminder 
- Issue with the reference material
- Issue with the Question Display
- Unable to access the assessment - TCERT-0016-CS01-V1-0-2018
- Unable to read one of the assessment post editing few questions
- unable to take one of the assessment post
- Issue with the Question Display in one of the assessment
- customer is unable to access enroll courses
- unable to access enroll
- unable to read the course
- i can't access course

## intent:User_Login_Issue
- User is unable to login into Indostar Site
- User was getting error while logging in Indostar Site
- getting error while logging
- User unable to login into Indostar site
- User was getting error while logging
- Unable to login into the Indostar
- Unable to login
- User unable to access the application
- User unable to access
- i can't login
- login issue is there
- login error
- can not login
- can't login into indostar
- while logging i can get error
- login issue
- login problem
- i may facing login problems
- facing login errors
- facing login issues


## intent:Course_Next_Button
- User Not able to exit after completing the course 
- Not able to exit
- User was not getting next button 
- not getting next button 
- User unable to click next button after assessment
- unable to click next button
- Next button was not working
- next button not working 
- User is not moving to next page
- not moving to next page
- User is unable to move to next slide
- unable to move to next slide
- cant able to exit
- can't able to click next button
- cant able to move
- i can't move next slides
- can't process after assessment 


## intent:Course_Creation
- Unable to edit the course
- unable to edit
- able to edit the course
- edit course
- cannot able to edit the course
- can't edit the course
- Map a course to a curriculum
- course to a curriculum
- Assessment movement from Staging to Production - AC Essentials and Troubleshooting
- Assessment movement 
- Assessment movement from Staging to Production
- AC Essentials and Troubleshooting
- i can't edit the course
- cannot edit the course


## intent:Asssessmet_Page_Activity
- Unable to select the options in the assessment
- Unable to select the options
- User was getting error while taking assessment
- getting error while taking assessment
- User was unable to mark scenerios like yes/no while taking assessment
- unable to mark scenerios like yes/no
- User unable to drag/drop the correct answer
- unable to drag/drop
- i can't select the option in the assessment
- i facing trouble in assessment page
- can't able to mark scenerios like yes/no
- problem on error in taking assessment 


## intent:acces_livewire
- how to access livewire
- how to access sify livewire
- connect livewire courses
- How to connect livewire 
- Do you want to access livewire?
- how can i do livewire login
- login livewire
- livewire enroll 
- how livewire can connect
- how could i connect livewire
- i meant want to login livewire
- livewire login
- connect access livewire
- lw
- want to login livewire
- live wire login
- login livewire
- hey show livewire login link 
- enroll livewire 


## intent:livewire_cours
- access livewire courses
- How do I access LiveWire Courses
- livewire courses
- course livewire
- which way i can access livewire courses


## intent:app_LiveWire
- advantage of livewire
- application of livewire 
- which application livewire can be used 
- livewire applications


## intent:goodbye
- cu
- good by
- cee you later
- good night
- good afternoon
- bye
- goodbye
- have a nice day
- see you around
- bye bye
- see you later

## intent:mood_affirm
- yes
- indeed
- of course
- that sounds good
- correct

## intent:mood_deny
- no
- never
- I don't think so
- don't like that
- no way
- not really

## intent:mood_great
- perfect
- not bad
- very good
- great
- i am fine
- am fine
- yeah i am fine 
- amazing
- feeling like a king
- wonderful
- I am feeling very good
- I am great
- I am amazing
- I am going to save the world
- super
- fine 
- ok 
- ok thanks
- thanks for your response
- thank you 
- good
- extremely good
- so so perfect
- so good
- so perfect

## intent:botname
- what is your name ?
- your name pls
- your name 
- say your name 
- your sweet name please
- tell your name
- hey bot what is your name
- hey what is you name 

## intent:helpuser
- how did you help me?
- how can you help me
- how did you help me
- you can help me 
- will u help me
- how could you help me
- could you please help me
- pls help me

## intent:botlanguage
- which language did you speak
- which language do you speak ?
- what language you will speak 
- how many language you may know 
- how many language you may know
- did you know english
- which language do you speak
- language you can speak
- which langauge do you speak
- do u know english

## intent:botage
- how old are you ?
- how old r u 
- how old are you
- old are you
- old are u
- old r u 
- your age 
- what is your age
- your age please
- age please
- age
- what is your age
- your age please?
- how old are you?

## intent:allcourse
- where do i find all courses?
- where i find allcourses
- find all course
- find courses
- where i can find all courses
- how can i find all courses


## intent:my_enroll_course
- where do i find my enrolled courses
- how can i find my enrolledcourse
- can i find my enrolled courses
- take my enrolled courses
- i want to find my enrolled courses


## intent:technical_course
- where do i find technical courses
- how can i find technical course
- find technical courses


## intent:comp_training
- where do i find my completed training 
- find my completed training courses
- how can i find my completed training courses
- find my training completed training courses 


## intent:softskill_course
- where do i find softskill courses
- how can i find softskill course
- how i can find my softskill course


## intent:launch_course
- how do i launch a course
- how can i launch my course
- how i can launch a course
- can i launch a course 


## intent:enroll_course
- how do i enroll for a course
- how can i enroll a course
- how can course enroll
- i can enroll course 
- where i can enroll my course



## intent:start_course
- how do i start a course
- how can i start a course
- how can i start my course
- i want to start my course

## intent:course_register
- How do I register for a course
- how i register a course
- how can i register a course 
- course register
- need to register course


## intent:self_register
- Do you want to self register for a course?

## intent:already_reg
- Do you want to check the courses which you had already registered?


## intent:course_search
- How do I search for a course
- how can i search a course
- search a course
- search course
- course search 
- i want to search a course 
- suggestion about search a course

## intent:specific_cours
- Do you want to search for a specific course in LiveWire?

## intent:global_search
- DO you want to perform a global search in LiveWire?


## intent:certificate
- Where do I get my certificates?
- where i get my all certificates
- how can i get my certificates 
- my certificates
- found my certificates
- get my certificate 

## intent:list_certificate
- Do you want to view the list of certificates which you have gained?


## intent:certificate_issue
- I am not seeing any certificates under Learner Dashboard
- certificates not found
- my completed certificates not found
- can not see my certificates 
- can't see my certificates 
- learner dashboard i can't see my certificates 
- under learner dashboard , not seeing any certificates 


## intent:transcript
- Where do I find my learning transcripts
- where i find my learning transcripts
- could u pls find learning transcripts
- find my learning transcripts
- how i can find my learning transcripts 

## intent:course_complt_issue
- I am unable to complete the course
- i can't able to complete my course
- can not able to complete the course


## intent:issue_comp_course
- Still not able to complete the course



## intent:Course_Prerequisite
- If there is a course which has a prerequisite, will the user have to take the pre requisite when the retraining starts?
- prerequisite
- course prerequisite
- take the pre requisite
- course which has a prerequisite

## intent:course_engine
- How does the course search engine works?
- how course engine work
- course search engine works
- search engine 
- search engine works 


## intent:Recommended_Course
- Where do I find the recommended courses in Learning Catalog?
- where i can find the recommended courses
- the recommended courses in Learning Catalog
- recommended courses
- how can i find my recommended courses
- how can i find my recommended course

## intent:Course_Create
- I am unable to create a learning/course in the system.
- can not create learning course in the system
- can't create learning courses
- not able to create learning course in my login

## intent:Email_Trigger
- I dont get any email notification on any of the learning assigned to me?
- i did't get email notification
- i can not get my email notifications 
- did not get my email notification
- not sending email notification

## intent:Training_Request
- How can I request for a learning program ?
- request for learning program
- learning program request
- shall i request learning program

## intent:Enrolment
- Courses assigned to me does not match my Role.
- courses does not match my role
- Courses assigned to me did not match my Role
- Courses assigned to me did't match my Role

## intent:Course_Assignment 
- Where can I find the courses which I will need to complete by this month/today/week


## intent:mood_unhappy
- my day was horrible
- I am sad
- i am not fine
- not fine
- shamefull
- not good
- so bad
- don't well
- very very bad
- I don't feel very well
- I am disappointed
- super sad
- I'm so sad
- sad
- very sad
- feeling bad
- unhappy
- bad
- very bad
- awful
- terrible
- not so good
- not very good
- extremly sad
- so sad

## intent:java_search
- Looking for course about [java](java_type)
- Looking for [java](java_type).
- Any interesting course [java technology](java_type) you can recommend?
- Would like to read some course about [java](java_type).
- Any recommendataions for [java](java_type) course to read?

## intent:paper_search
- Looking for papers about [chatbots](paper_type)
- Please suggest some interesting papers to read
- Looking for some new papers about [machine learning](paper_type)
- Any recommendataions for [statistics](paper_type) papers to read?
- I have some spare time and would like to read some [mathematics](paper_type) papers.
- Looking for papers to read
- Do you have new papers to recommend?
- Would like to read some papers about [physics](paper_type).
- Please recommend some interesting papers about [astronomy](paper_type).
- Looking for [econometrics](paper_type) papers.
- Looking for papers in [artificial intelligence](paper_type)
- Please share some papers to read
- Looking for [Physics](paper_type) to read.
- Can you recommend me [Mathematics](paper_type)?
- Any interesting papers [statistics](paper_type) you can recommend?

## intent:enroll
- i want to [enroll](enroll_type)
- need to [enroll id](enroll_type)
- how to i enroll [id enroll](enroll_type)a course 

## intent:inform
- about [statistics](paper_type)
- maybe [mathematics](paper_type)
- about [geography](paper_type)
- for [machine learning](paper_type)
- about [differentiation](paper_type)
- maybe about [calculus](paper_type)

"""

# %store nlu_md > nlu.md
# Out:
# Writing 'nlu_md' (str) to file 'nlu.md'.

# %% [markdown]
# ## Defining the NLU Model Configuration

# %%
config = """
language: "en"

pipeline:
- name: "WhitespaceTokenizer"
- name: "RegexFeaturizer"
- name: "CRFEntityExtractor"
- name: "EntitySynonymMapper"
- name: "CountVectorsFeaturizer"
- name: "CountVectorsFeaturizer"
  analyzer: "char_wb"
  min_ngram: 1
  max_ngram: 4
- name: "EmbeddingIntentClassifier"
""" 

# %store config > config.yml
# Out:
# Writing 'config' (str) to file 'config.yml'.

# %% [markdown]
# ## Training the NLU Model

# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config

# loading the nlu training samples
training_data = load_data("nlu.md")

# trainer to educate our pipeline
trainer = Trainer(config.load("config.yml"))

# train the model!
interpreter = trainer.train(training_data)

# store it for future use
model_directory = trainer.persist("./models/nlu", fixed_model_name="current")
# Out:
# INFO:rasa_nlu.training_data.loading:Training data format of nlu.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 380 (51 distinct intents)
# 	- Found intents: 'certificate_issue', 'Course_Creation', 'Course_Assignment', 'softskill_course', 'mood_affirm', 'course_engine', 'goodbye', 'list_certificate', 'course_complt_issue', 'Course_Prerequisite', 'Recommended_Course', 'Training_Request', 'mood_unhappy', 'java_search', 'Course_Next_Button', 'comp_training', 'Enrolment', 'greet', 'helpuser', 'self_register', 'botname', 'acces_livewire', 'Asssessmet_Page_Activity', 'launch_course', 'enroll_course', 'Course_Create', 'botlanguage', 'transcript', 'botage', 'Course_Launch_Issue', 'start_course', 'mood_deny', 'course_register', 'allcourse', 'specific_cours', 'User_Login_Issue', 'my_enroll_course', 'technical_course', 'certificate', 'mood_great', 'app_LiveWire', 'LIVEWIRE', 'issue_comp_course', 'inform', 'paper_search', 'already_reg', 'enroll', 'Email_Trigger', 'course_search', 'global_search', 'livewire_cours'
# 	- entity examples: 25 (3 distinct entities)
# 	- found entities: 'java_type', 'paper_type', 'enroll_type'
#
# INFO:rasa_nlu.model:Starting to train component WhitespaceTokenizer
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component RegexFeaturizer
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component CRFEntityExtractor
# WARNING:rasa_nlu.extractors.crf_entity_extractor:Misaligned entity annotation in sentence 'how to i enroll id enrolla course'. Make sure the start and end values of the annotated training examples end at token boundaries (e.g. don't include trailing whitespaces or punctuation).
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component EntitySynonymMapper
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component CountVectorsFeaturizer
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component CountVectorsFeaturizer
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component EmbeddingIntentClassifier
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
# WARNING:tensorflow:From E:\ANACONDA\lib\site-packages\rasa_nlu\classifiers\embedding_intent_classifier.py:285: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From E:\ANACONDA\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From E:\ANACONDA\lib\site-packages\rasa_nlu\classifiers\embedding_intent_classifier.py:286: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From E:\ANACONDA\lib\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From E:\ANACONDA\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From E:\ANACONDA\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# INFO:rasa_nlu.classifiers.embedding_intent_classifier:Accuracy is updated every 10 epochs
# Epochs: 100%|█████████████████████████████████████████████████| 300/300 [00:14<00:00, 21.62it/s, loss=0.126, acc=0.997]
# INFO:rasa_nlu.classifiers.embedding_intent_classifier:Finished training embedding classifier, loss=0.126, train accuracy=0.997
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Successfully saved model into 'C:\Users\015864\Sify_Chat_bot_livewire1.1 (Custom API action)\models\nlu\default\current'

# %% [markdown]
# ## Evaluating the NLU model on a random text

# %%
# A helper function for prettier output

def pprint(o):   
    print(json.dumps(o, indent=2))
    
#pprint(interpreter.parse("I am very sad"))
#pprint(interpreter.parse("what is pal"))
pprint(interpreter.parse("Where can I find the courses which I will need to complete by this month/today/week"))
#pprint(interpreter.parse("looking for course about java"))
# Out:
# {
#   "intent": {
#     "name": "Course_Assignment",
#     "confidence": 0.9513627290725708
#   },
#   "entities": [],
#   "intent_ranking": [
#     {
#       "name": "Course_Assignment",
#       "confidence": 0.9513627290725708
#     },
#     {
#       "name": "softskill_course",
#       "confidence": 0.2507435381412506
#     },
#     {
#       "name": "Enrolment",
#       "confidence": 0.24507838487625122
#     },
#     {
#       "name": "mood_deny",
#       "confidence": 0.2400752305984497
#     },
#     {
#       "name": "LIVEWIRE",
#       "confidence": 0.21836057305335999
#     },
#     {
#       "name": "botlanguage",
#       "confidence": 0.19772493839263916
#     },
#     {
#       "name": "Asssessmet_Page_Activity",
#       "confidence": 0.18775208294391632
#     },
#     {
#       "name": "list_certificate",
#       "confidence": 0.16315032541751862
#     },
#     {
#       "name": "mood_great",
#       "confidence": 0.13570672273635864
#     },
#     {
#       "name": "app_LiveWire",
#       "confidence": 0.1304214894771576
#     }
#   ],
#   "text": "Where can I find the courses which I will need to complete by this month/today/week"
# }

# %% [markdown]
# ### Evaluating the NLU model on a test data
# (Here we are using the data at hand i.e nlu.md but it isr recommended to use unseen data)

# %%
from rasa_nlu.test import run_evaluation

run_evaluation("nlu.md", model_directory)
# Out:
# WARNING:tensorflow:From E:\ANACONDA\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from C:\Users\015864\Sify_Chat_bot_livewire1.1 (Custom API action)\./models/nlu\default\current\component_6_EmbeddingIntentClassifier.ckpt
# INFO:rasa_nlu.training_data.loading:Training data format of nlu.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 380 (51 distinct intents)
# 	- Found intents: 'certificate_issue', 'Course_Creation', 'Course_Assignment', 'softskill_course', 'mood_affirm', 'course_engine', 'goodbye', 'list_certificate', 'course_complt_issue', 'Course_Prerequisite', 'Recommended_Course', 'Training_Request', 'mood_unhappy', 'java_search', 'Course_Next_Button', 'comp_training', 'Enrolment', 'greet', 'helpuser', 'self_register', 'botname', 'acces_livewire', 'Asssessmet_Page_Activity', 'launch_course', 'enroll_course', 'Course_Create', 'botlanguage', 'transcript', 'botage', 'Course_Launch_Issue', 'start_course', 'mood_deny', 'course_register', 'allcourse', 'specific_cours', 'User_Login_Issue', 'my_enroll_course', 'technical_course', 'certificate', 'mood_great', 'app_LiveWire', 'LIVEWIRE', 'issue_comp_course', 'inform', 'paper_search', 'already_reg', 'enroll', 'Email_Trigger', 'course_search', 'global_search', 'livewire_cours'
# 	- entity examples: 25 (3 distinct entities)
# 	- found entities: 'java_type', 'paper_type', 'enroll_type'
#
# INFO:rasa_nlu.test:Running model for predictions:
# 100%|███████████████████████████████████████████████████████████████████████████████| 380/380 [00:00<00:00, 911.45it/s]
# INFO:rasa_nlu.test:Intent evaluation results:
# INFO:rasa_nlu.test:Intent Evaluation: Only considering those 380 examples that have a defined intent out of 380 examples
# INFO:rasa_nlu.test:F1-Score:  0.9973544973544972
# INFO:rasa_nlu.test:Precision: 0.9975563909774435
# INFO:rasa_nlu.test:Accuracy:  0.9973684210526316
# INFO:rasa_nlu.test:Classification report:
#                           precision    recall  f1-score   support
#
# Asssessmet_Page_Activity       1.00      1.00      1.00        12
#        Course_Assignment       1.00      1.00      1.00         1
#            Course_Create       1.00      1.00      1.00         4
#          Course_Creation       1.00      1.00      1.00        14
#      Course_Launch_Issue       1.00      1.00      1.00        17
#       Course_Next_Button       1.00      1.00      1.00        17
#      Course_Prerequisite       1.00      1.00      1.00         5
#            Email_Trigger       1.00      1.00      1.00         5
#                Enrolment       1.00      1.00      1.00         4
#                 LIVEWIRE       1.00      1.00      1.00        11
#       Recommended_Course       1.00      1.00      1.00         6
#         Training_Request       1.00      1.00      1.00         4
#         User_Login_Issue       1.00      1.00      1.00        20
#           acces_livewire       1.00      1.00      1.00        19
#                allcourse       1.00      1.00      1.00         6
#              already_reg       1.00      1.00      1.00         1
#             app_LiveWire       1.00      1.00      1.00         4
#                   botage       1.00      1.00      1.00        14
#              botlanguage       1.00      1.00      1.00        10
#                  botname       1.00      1.00      1.00         8
#              certificate       1.00      1.00      1.00         6
#        certificate_issue       1.00      1.00      1.00         7
#            comp_training       1.00      1.00      1.00         4
#      course_complt_issue       1.00      1.00      1.00         3
#            course_engine       1.00      1.00      1.00         5
#          course_register       1.00      1.00      1.00         5
#            course_search       1.00      1.00      1.00         7
#                   enroll       1.00      1.00      1.00         3
#            enroll_course       1.00      1.00      1.00         5
#            global_search       1.00      1.00      1.00         1
#                  goodbye       1.00      0.91      0.95        11
#                    greet       0.93      1.00      0.96        13
#                 helpuser       1.00      1.00      1.00         8
#                   inform       1.00      1.00      1.00         6
#        issue_comp_course       1.00      1.00      1.00         1
#              java_search       1.00      1.00      1.00         5
#            launch_course       1.00      1.00      1.00         4
#         list_certificate       1.00      1.00      1.00         1
#           livewire_cours       1.00      1.00      1.00         5
#              mood_affirm       1.00      1.00      1.00         5
#                mood_deny       1.00      1.00      1.00         6
#               mood_great       1.00      1.00      1.00        25
#             mood_unhappy       1.00      1.00      1.00        25
#         my_enroll_course       1.00      1.00      1.00         5
#             paper_search       1.00      1.00      1.00        15
#            self_register       1.00      1.00      1.00         1
#         softskill_course       1.00      1.00      1.00         3
#           specific_cours       1.00      1.00      1.00         1
#             start_course       1.00      1.00      1.00         4
#         technical_course       1.00      1.00      1.00         3
#               transcript       1.00      1.00      1.00         5
#
#                micro avg       1.00      1.00      1.00       380
#                macro avg       1.00      1.00      1.00       380
#             weighted avg       1.00      1.00      1.00       380
#
# INFO:rasa_nlu.test:Model prediction errors saved to errors.json.
# INFO:rasa_nlu.test:Entity evaluation results:
# INFO:rasa_nlu.test:Evaluation for entity extractor: CRFEntityExtractor
# INFO:rasa_nlu.test:F1-Score:  0.9978962826226251
# INFO:rasa_nlu.test:Precision: 0.9982699507750111
# INFO:rasa_nlu.test:Accuracy:  0.9982668977469671
# INFO:rasa_nlu.test:Classification report:
#               precision    recall  f1-score   support
#
#  enroll_type       1.00      0.40      0.57         5
#    java_type       1.00      1.00      1.00         6
#    no_entity       1.00      1.00      1.00      1700
#   paper_type       1.00      1.00      1.00        20
#
#    micro avg       1.00      1.00      1.00      1731
#    macro avg       1.00      0.85      0.89      1731
# weighted avg       1.00      1.00      1.00      1731
# {'intent_evaluation': {'predictions': [{'text': 'hey',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9760633111000061},
#    {'text': 'hello there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9774395227432251},
#    {'text': 'hi',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9764753580093384},
#    {'text': 'hello there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9774395227432251},
#    {'text': 'good morning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9694380760192871},
#    {'text': 'good evening',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9488917589187622},
#    {'text': 'hi chatbot',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9668917655944824},
#    {'text': 'hey there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9713451862335205},
#    {'text': "let's go",
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9673764705657959},
#    {'text': 'hey dude',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9726434350013733},
#    {'text': 'goodmorning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9642447233200073},
#    {'text': 'goodevening',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9603868126869202},
#    {'text': 'good afternoon',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.7421069741249084},
#    {'text': 'livewire',
#     'intent': 'LIVEWIRE',
#     'predicted': 'LIVEWIRE',
#     'confidence': 0.9515395760536194},
#    {'text': 'livewire',
#     'intent': 'LIVEWIRE',
#     'predicted': 'LIVEWIRE',
#     'confidence': 0.9515395760536194},
#    {'text': 'what is livewire',
#     'intent': 'LIVEWIRE',
#     'predicted': 'LIVEWIRE',
#     'confidence': 0.9482283592224121},
#    {'text': 'define livewire',
#     'intent': 'LIVEWIRE',
#     'predicted': 'LIVEWIRE',
#     'confidence': 0.9379498958587646},
#    {'text': 'context of livewire',
#     'intent': 'LIVEWIRE',
#     'predicted': 'LIVEWIRE',
#     'confidence': 0.9302924871444702},
#    {'text': 'could you please give what do you meant livewire',
#     'intent': 'LIVEWIRE',
#     'predicted': 'LIVEWIRE',
#     'confidence': 0.9071179628372192},
#    {'text': 'content of livewire',
#     'intent': 'LIVEWIRE',
#     'predicted': 'LIVEWIRE',
#     'confidence': 0.934849739074707},
#    {'text': 'what do you meant livewire?',
#     'intent': 'LIVEWIRE',
#     'predicted': 'LIVEWIRE',
#     'confidence': 0.9372804164886475},
#    {'text': 'say something about livewire',
#     'intent': 'LIVEWIRE',
#     'predicted': 'LIVEWIRE',
#     'confidence': 0.9426296949386597},
#    {'text': 'about livewire',
#     'intent': 'LIVEWIRE',
#     'predicted': 'LIVEWIRE',
#     'confidence': 0.9457203149795532},
#    {'text': 'brief about livewire',
#     'intent': 'LIVEWIRE',
#     'predicted': 'LIVEWIRE',
#     'confidence': 0.9428155422210693},
#    {'text': 'I am unable to launch the course',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9659386873245239},
#    {'text': 'Error in the assessment launch',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9723381400108337},
#    {'text': 'error in the assessment launch',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9723381400108337},
#    {'text': 'Issue while taking the assessment',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9625795483589172},
#    {'text': 'Issue with the reference material mapping in Curriculum',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9828183650970459},
#    {'text': 'Gentle reminder -Get Enabled, Get Certified || NOC Services',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9640495777130127},
#    {'text': 'Gentle reminder',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.971758246421814},
#    {'text': 'Issue with the reference material',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9814536571502686},
#    {'text': 'Issue with the Question Display',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9719343781471252},
#    {'text': 'Unable to access the assessment - TCERT-0016-CS01-V1-0-2018',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9573936462402344},
#    {'text': 'Unable to read one of the assessment post editing few questions',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9677549004554749},
#    {'text': 'unable to take one of the assessment post',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9637137651443481},
#    {'text': 'Issue with the Question Display in one of the assessment',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9656850695610046},
#    {'text': 'customer is unable to access enroll courses',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9810305833816528},
#    {'text': 'unable to access enroll',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9745516180992126},
#    {'text': 'unable to read the course',
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9674544930458069},
#    {'text': "i can't access course",
#     'intent': 'Course_Launch_Issue',
#     'predicted': 'Course_Launch_Issue',
#     'confidence': 0.9723358154296875},
#    {'text': 'User is unable to login into Indostar Site',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9559416770935059},
#    {'text': 'User was getting error while logging in Indostar Site',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9521571397781372},
#    {'text': 'getting error while logging',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9479392766952515},
#    {'text': 'User unable to login into Indostar site',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9456952214241028},
#    {'text': 'User was getting error while logging',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9614976644515991},
#    {'text': 'Unable to login into the Indostar',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9159581065177917},
#    {'text': 'Unable to login',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9609656929969788},
#    {'text': 'User unable to access the application',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9642019867897034},
#    {'text': 'User unable to access',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9509521722793579},
#    {'text': "i can't login",
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9630820751190186},
#    {'text': 'login issue is there',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9684404730796814},
#    {'text': 'login error',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.953623354434967},
#    {'text': 'can not login',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9376535415649414},
#    {'text': "can't login into indostar",
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9409055113792419},
#    {'text': 'while logging i can get error',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9629581570625305},
#    {'text': 'login issue',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9729837775230408},
#    {'text': 'login problem',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.957477867603302},
#    {'text': 'i may facing login problems',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9552786350250244},
#    {'text': 'facing login errors',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9555293321609497},
#    {'text': 'facing login issues',
#     'intent': 'User_Login_Issue',
#     'predicted': 'User_Login_Issue',
#     'confidence': 0.9678069353103638},
#    {'text': 'User Not able to exit after completing the course',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9411339163780212},
#    {'text': 'Not able to exit',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9703834056854248},
#    {'text': 'User was not getting next button',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.967206597328186},
#    {'text': 'not getting next button',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9593914747238159},
#    {'text': 'User unable to click next button after assessment',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9758841395378113},
#    {'text': 'unable to click next button',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9064231514930725},
#    {'text': 'Next button was not working',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9574465751647949},
#    {'text': 'next button not working',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9703952074050903},
#    {'text': 'User is not moving to next page',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9778364896774292},
#    {'text': 'not moving to next page',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.977831244468689},
#    {'text': 'User is unable to move to next slide',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9661257266998291},
#    {'text': 'unable to move to next slide',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9561309814453125},
#    {'text': 'cant able to exit',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9684712886810303},
#    {'text': "can't able to click next button",
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9545801281929016},
#    {'text': 'cant able to move',
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.956376314163208},
#    {'text': "i can't move next slides",
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9669001698493958},
#    {'text': "can't process after assessment",
#     'intent': 'Course_Next_Button',
#     'predicted': 'Course_Next_Button',
#     'confidence': 0.9632505178451538},
#    {'text': 'Unable to edit the course',
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9467141032218933},
#    {'text': 'unable to edit',
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9632158875465393},
#    {'text': 'able to edit the course',
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9475154876708984},
#    {'text': 'edit course',
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9517212510108948},
#    {'text': 'cannot able to edit the course',
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9579796195030212},
#    {'text': "can't edit the course",
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9594892859458923},
#    {'text': 'Map a course to a curriculum',
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9545523524284363},
#    {'text': 'course to a curriculum',
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.956336259841919},
#    {'text': 'Assessment movement from Staging to Production - AC Essentials and Troubleshooting',
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9745118021965027},
#    {'text': 'Assessment movement',
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9168432354927063},
#    {'text': 'Assessment movement from Staging to Production',
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9659489393234253},
#    {'text': 'AC Essentials and Troubleshooting',
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9415110349655151},
#    {'text': "i can't edit the course",
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9541810750961304},
#    {'text': 'cannot edit the course',
#     'intent': 'Course_Creation',
#     'predicted': 'Course_Creation',
#     'confidence': 0.9665594696998596},
#    {'text': 'Unable to select the options in the assessment',
#     'intent': 'Asssessmet_Page_Activity',
#     'predicted': 'Asssessmet_Page_Activity',
#     'confidence': 0.9673805236816406},
#    {'text': 'Unable to select the options',
#     'intent': 'Asssessmet_Page_Activity',
#     'predicted': 'Asssessmet_Page_Activity',
#     'confidence': 0.9423121213912964},
#    {'text': 'User was getting error while taking assessment',
#     'intent': 'Asssessmet_Page_Activity',
#     'predicted': 'Asssessmet_Page_Activity',
#     'confidence': 0.9708312153816223},
#    {'text': 'getting error while taking assessment',
#     'intent': 'Asssessmet_Page_Activity',
#     'predicted': 'Asssessmet_Page_Activity',
#     'confidence': 0.9541617035865784},
#    {'text': 'User was unable to mark scenerios like yes/no while taking assessment',
#     'intent': 'Asssessmet_Page_Activity',
#     'predicted': 'Asssessmet_Page_Activity',
#     'confidence': 0.9798933267593384},
#    {'text': 'unable to mark scenerios like yes/no',
#     'intent': 'Asssessmet_Page_Activity',
#     'predicted': 'Asssessmet_Page_Activity',
#     'confidence': 0.9812065362930298},
#    {'text': 'User unable to drag/drop the correct answer',
#     'intent': 'Asssessmet_Page_Activity',
#     'predicted': 'Asssessmet_Page_Activity',
#     'confidence': 0.9740073084831238},
#    {'text': 'unable to drag/drop',
#     'intent': 'Asssessmet_Page_Activity',
#     'predicted': 'Asssessmet_Page_Activity',
#     'confidence': 0.9675534963607788},
#    {'text': "i can't select the option in the assessment",
#     'intent': 'Asssessmet_Page_Activity',
#     'predicted': 'Asssessmet_Page_Activity',
#     'confidence': 0.9493604302406311},
#    {'text': 'i facing trouble in assessment page',
#     'intent': 'Asssessmet_Page_Activity',
#     'predicted': 'Asssessmet_Page_Activity',
#     'confidence': 0.9663403630256653},
#    {'text': "can't able to mark scenerios like yes/no",
#     'intent': 'Asssessmet_Page_Activity',
#     'predicted': 'Asssessmet_Page_Activity',
#     'confidence': 0.9687560796737671},
#    {'text': 'problem on error in taking assessment',
#     'intent': 'Asssessmet_Page_Activity',
#     'predicted': 'Asssessmet_Page_Activity',
#     'confidence': 0.9675076603889465},
#    {'text': 'how to access livewire',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9771241545677185},
#    {'text': 'how to access sify livewire',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9746091365814209},
#    {'text': 'connect livewire courses',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.965434730052948},
#    {'text': 'How to connect livewire',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9653124809265137},
#    {'text': 'Do you want to access livewire?',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9428454041481018},
#    {'text': 'how can i do livewire login',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9542883038520813},
#    {'text': 'login livewire',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9692212343215942},
#    {'text': 'livewire enroll',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9494996666908264},
#    {'text': 'how livewire can connect',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9666150808334351},
#    {'text': 'how could i connect livewire',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9683875441551208},
#    {'text': 'i meant want to login livewire',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9765682220458984},
#    {'text': 'livewire login',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9692212343215942},
#    {'text': 'connect access livewire',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.961280345916748},
#    {'text': 'lw',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9779646992683411},
#    {'text': 'want to login livewire',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9758824706077576},
#    {'text': 'live wire login',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9675760865211487},
#    {'text': 'login livewire',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9692212343215942},
#    {'text': 'hey show livewire login link',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9728419184684753},
#    {'text': 'enroll livewire',
#     'intent': 'acces_livewire',
#     'predicted': 'acces_livewire',
#     'confidence': 0.9494996666908264},
#    {'text': 'access livewire courses',
#     'intent': 'livewire_cours',
#     'predicted': 'livewire_cours',
#     'confidence': 0.9588267207145691},
#    {'text': 'How do I access LiveWire Courses',
#     'intent': 'livewire_cours',
#     'predicted': 'livewire_cours',
#     'confidence': 0.9390422105789185},
#    {'text': 'livewire courses',
#     'intent': 'livewire_cours',
#     'predicted': 'livewire_cours',
#     'confidence': 0.9693824052810669},
#    {'text': 'course livewire',
#     'intent': 'livewire_cours',
#     'predicted': 'livewire_cours',
#     'confidence': 0.9593695998191833},
#    {'text': 'which way i can access livewire courses',
#     'intent': 'livewire_cours',
#     'predicted': 'livewire_cours',
#     'confidence': 0.9131587147712708},
#    {'text': 'advantage of livewire',
#     'intent': 'app_LiveWire',
#     'predicted': 'app_LiveWire',
#     'confidence': 0.909281849861145},
#    {'text': 'application of livewire',
#     'intent': 'app_LiveWire',
#     'predicted': 'app_LiveWire',
#     'confidence': 0.9317911863327026},
#    {'text': 'which application livewire can be used',
#     'intent': 'app_LiveWire',
#     'predicted': 'app_LiveWire',
#     'confidence': 0.9393987655639648},
#    {'text': 'livewire applications',
#     'intent': 'app_LiveWire',
#     'predicted': 'app_LiveWire',
#     'confidence': 0.9348311424255371},
#    {'text': 'cu',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9506949782371521},
#    {'text': 'good by',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.948881983757019},
#    {'text': 'cee you later',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9337171912193298},
#    {'text': 'good night',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9432392716407776},
#    {'text': 'good afternoon',
#     'intent': 'goodbye',
#     'predicted': 'greet',
#     'confidence': 0.7421069741249084},
#    {'text': 'bye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9504454731941223},
#    {'text': 'goodbye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9493171572685242},
#    {'text': 'have a nice day',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9497765302658081},
#    {'text': 'see you around',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9614519476890564},
#    {'text': 'bye bye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9430290460586548},
#    {'text': 'see you later',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9464735984802246},
#    {'text': 'yes',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9364579916000366},
#    {'text': 'indeed',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.8989226222038269},
#    {'text': 'of course',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9107028841972351},
#    {'text': 'that sounds good',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9362087249755859},
#    {'text': 'correct',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9604759216308594},
#    {'text': 'no',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.948409914970398},
#    {'text': 'never',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9370813369750977},
#    {'text': "I don't think so",
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9435527324676514},
#    {'text': "don't like that",
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9409640431404114},
#    {'text': 'no way',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9531102180480957},
#    {'text': 'not really',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9438133835792542},
#    {'text': 'perfect',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9685943722724915},
#    {'text': 'not bad',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9166121482849121},
#    {'text': 'very good',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9517554640769958},
#    {'text': 'great',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9473959803581238},
#    {'text': 'i am fine',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9314159154891968},
#    {'text': 'am fine',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9372670650482178},
#    {'text': 'yeah i am fine',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9539499878883362},
#    {'text': 'amazing',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9520848989486694},
#    {'text': 'feeling like a king',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9607723355293274},
#    {'text': 'wonderful',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9201672077178955},
#    {'text': 'I am feeling very good',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9393334984779358},
#    {'text': 'I am great',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9415592551231384},
#    {'text': 'I am amazing',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.913597583770752},
#    {'text': 'I am going to save the world',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9540462493896484},
#    {'text': 'super',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9753038883209229},
#    {'text': 'fine',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9045348167419434},
#    {'text': 'ok',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9704577922821045},
#    {'text': 'ok thanks',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9739943742752075},
#    {'text': 'thanks for your response',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9655622243881226},
#    {'text': 'thank you',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9612442851066589},
#    {'text': 'good',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9383657574653625},
#    {'text': 'extremely good',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9494317173957825},
#    {'text': 'so so perfect',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9682502746582031},
#    {'text': 'so good',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9541836977005005},
#    {'text': 'so perfect',
#     'intent': 'mood_great',
#     'predicted': 'mood_great',
#     'confidence': 0.9689335823059082},
#    {'text': 'what is your name ?',
#     'intent': 'botname',
#     'predicted': 'botname',
#     'confidence': 0.9522704482078552},
#    {'text': 'your name pls',
#     'intent': 'botname',
#     'predicted': 'botname',
#     'confidence': 0.9478276968002319},
#    {'text': 'your name',
#     'intent': 'botname',
#     'predicted': 'botname',
#     'confidence': 0.9542878270149231},
#    {'text': 'say your name',
#     'intent': 'botname',
#     'predicted': 'botname',
#     'confidence': 0.9527537226676941},
#    {'text': 'your sweet name please',
#     'intent': 'botname',
#     'predicted': 'botname',
#     'confidence': 0.9287970662117004},
#    {'text': 'tell your name',
#     'intent': 'botname',
#     'predicted': 'botname',
#     'confidence': 0.9311341643333435},
#    {'text': 'hey bot what is your name',
#     'intent': 'botname',
#     'predicted': 'botname',
#     'confidence': 0.9580538868904114},
#    {'text': 'hey what is you name',
#     'intent': 'botname',
#     'predicted': 'botname',
#     'confidence': 0.9491322636604309},
#    {'text': 'how did you help me?',
#     'intent': 'helpuser',
#     'predicted': 'helpuser',
#     'confidence': 0.9833354949951172},
#    {'text': 'how can you help me',
#     'intent': 'helpuser',
#     'predicted': 'helpuser',
#     'confidence': 0.9740352034568787},
#    {'text': 'how did you help me',
#     'intent': 'helpuser',
#     'predicted': 'helpuser',
#     'confidence': 0.9833354949951172},
#    {'text': 'you can help me',
#     'intent': 'helpuser',
#     'predicted': 'helpuser',
#     'confidence': 0.9535900354385376},
#    {'text': 'will u help me',
#     'intent': 'helpuser',
#     'predicted': 'helpuser',
#     'confidence': 0.9690582752227783},
#    {'text': 'how could you help me',
#     'intent': 'helpuser',
#     'predicted': 'helpuser',
#     'confidence': 0.9820157289505005},
#    {'text': 'could you please help me',
#     'intent': 'helpuser',
#     'predicted': 'helpuser',
#     'confidence': 0.965384304523468},
#    {'text': 'pls help me',
#     'intent': 'helpuser',
#     'predicted': 'helpuser',
#     'confidence': 0.9734120965003967},
#    {'text': 'which language did you speak',
#     'intent': 'botlanguage',
#     'predicted': 'botlanguage',
#     'confidence': 0.9617379307746887},
#    {'text': 'which language do you speak ?',
#     'intent': 'botlanguage',
#     'predicted': 'botlanguage',
#     'confidence': 0.9572175741195679},
#    {'text': 'what language you will speak',
#     'intent': 'botlanguage',
#     'predicted': 'botlanguage',
#     'confidence': 0.9551697373390198},
#    {'text': 'how many language you may know',
#     'intent': 'botlanguage',
#     'predicted': 'botlanguage',
#     'confidence': 0.9631344079971313},
#    {'text': 'how many language you may know',
#     'intent': 'botlanguage',
#     'predicted': 'botlanguage',
#     'confidence': 0.9631344079971313},
#    {'text': 'did you know english',
#     'intent': 'botlanguage',
#     'predicted': 'botlanguage',
#     'confidence': 0.9382880330085754},
#    {'text': 'which language do you speak',
#     'intent': 'botlanguage',
#     'predicted': 'botlanguage',
#     'confidence': 0.9572175741195679},
#    {'text': 'language you can speak',
#     'intent': 'botlanguage',
#     'predicted': 'botlanguage',
#     'confidence': 0.943667471408844},
#    {'text': 'which langauge do you speak',
#     'intent': 'botlanguage',
#     'predicted': 'botlanguage',
#     'confidence': 0.9552469253540039},
#    {'text': 'do u know english',
#     'intent': 'botlanguage',
#     'predicted': 'botlanguage',
#     'confidence': 0.9241430759429932},
#    {'text': 'how old are you ?',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.9640693068504333},
#    {'text': 'how old r u',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.9528931975364685},
#    {'text': 'how old are you',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.9640693068504333},
#    {'text': 'old are you',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.9480955600738525},
#    {'text': 'old are u',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.9435722231864929},
#    {'text': 'old r u',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.9470421075820923},
#    {'text': 'your age',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.9700959324836731},
#    {'text': 'what is your age',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.9594326615333557},
#    {'text': 'your age please',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.954206109046936},
#    {'text': 'age please',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.9473536610603333},
#    {'text': 'age',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.9496174454689026},
#    {'text': 'what is your age',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.9594326615333557},
#    {'text': 'your age please?',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.954206109046936},
#    {'text': 'how old are you?',
#     'intent': 'botage',
#     'predicted': 'botage',
#     'confidence': 0.9640693068504333},
#    {'text': 'where do i find all courses?',
#     'intent': 'allcourse',
#     'predicted': 'allcourse',
#     'confidence': 0.9092885255813599},
#    {'text': 'where i find allcourses',
#     'intent': 'allcourse',
#     'predicted': 'allcourse',
#     'confidence': 0.9430930018424988},
#    {'text': 'find all course',
#     'intent': 'allcourse',
#     'predicted': 'allcourse',
#     'confidence': 0.9236872792243958},
#    {'text': 'find courses',
#     'intent': 'allcourse',
#     'predicted': 'allcourse',
#     'confidence': 0.9169737100601196},
#    {'text': 'where i can find all courses',
#     'intent': 'allcourse',
#     'predicted': 'allcourse',
#     'confidence': 0.9285938143730164},
#    {'text': 'how can i find all courses',
#     'intent': 'allcourse',
#     'predicted': 'allcourse',
#     'confidence': 0.9189038872718811},
#    {'text': 'where do i find my enrolled courses',
#     'intent': 'my_enroll_course',
#     'predicted': 'my_enroll_course',
#     'confidence': 0.9186335206031799},
#    {'text': 'how can i find my enrolledcourse',
#     'intent': 'my_enroll_course',
#     'predicted': 'my_enroll_course',
#     'confidence': 0.924839198589325},
#    {'text': 'can i find my enrolled courses',
#     'intent': 'my_enroll_course',
#     'predicted': 'my_enroll_course',
#     'confidence': 0.9129534959793091},
#    {'text': 'take my enrolled courses',
#     'intent': 'my_enroll_course',
#     'predicted': 'my_enroll_course',
#     'confidence': 0.9348809123039246},
#    {'text': 'i want to find my enrolled courses',
#     'intent': 'my_enroll_course',
#     'predicted': 'my_enroll_course',
#     'confidence': 0.9085356593132019},
#    {'text': 'where do i find technical courses',
#     'intent': 'technical_course',
#     'predicted': 'technical_course',
#     'confidence': 0.9119265079498291},
#    {'text': 'how can i find technical course',
#     'intent': 'technical_course',
#     'predicted': 'technical_course',
#     'confidence': 0.9204195737838745},
#    {'text': 'find technical courses',
#     'intent': 'technical_course',
#     'predicted': 'technical_course',
#     'confidence': 0.9392937421798706},
#    {'text': 'where do i find my completed training',
#     'intent': 'comp_training',
#     'predicted': 'comp_training',
#     'confidence': 0.9276840090751648},
#    {'text': 'find my completed training courses',
#     'intent': 'comp_training',
#     'predicted': 'comp_training',
#     'confidence': 0.9644943475723267},
#    {'text': 'how can i find my completed training courses',
#     'intent': 'comp_training',
#     'predicted': 'comp_training',
#     'confidence': 0.953848123550415},
#    {'text': 'find my training completed training courses',
#     'intent': 'comp_training',
#     'predicted': 'comp_training',
#     'confidence': 0.9579238891601562},
#    {'text': 'where do i find softskill courses',
#     'intent': 'softskill_course',
#     'predicted': 'softskill_course',
#     'confidence': 0.945256769657135},
#    {'text': 'how can i find softskill course',
#     'intent': 'softskill_course',
#     'predicted': 'softskill_course',
#     'confidence': 0.9478111863136292},
#    {'text': 'how i can find my softskill course',
#     'intent': 'softskill_course',
#     'predicted': 'softskill_course',
#     'confidence': 0.9471724629402161},
#    {'text': 'how do i launch a course',
#     'intent': 'launch_course',
#     'predicted': 'launch_course',
#     'confidence': 0.9357414245605469},
#    {'text': 'how can i launch my course',
#     'intent': 'launch_course',
#     'predicted': 'launch_course',
#     'confidence': 0.9424703121185303},
#    {'text': 'how i can launch a course',
#     'intent': 'launch_course',
#     'predicted': 'launch_course',
#     'confidence': 0.951723575592041},
#    {'text': 'can i launch a course',
#     'intent': 'launch_course',
#     'predicted': 'launch_course',
#     'confidence': 0.9483153820037842},
#    {'text': 'how do i enroll for a course',
#     'intent': 'enroll_course',
#     'predicted': 'enroll_course',
#     'confidence': 0.9499645233154297},
#    {'text': 'how can i enroll a course',
#     'intent': 'enroll_course',
#     'predicted': 'enroll_course',
#     'confidence': 0.9523756504058838},
#    {'text': 'how can course enroll',
#     'intent': 'enroll_course',
#     'predicted': 'enroll_course',
#     'confidence': 0.9408274292945862},
#    {'text': 'i can enroll course',
#     'intent': 'enroll_course',
#     'predicted': 'enroll_course',
#     'confidence': 0.9392551779747009},
#    {'text': 'where i can enroll my course',
#     'intent': 'enroll_course',
#     'predicted': 'enroll_course',
#     'confidence': 0.9537023305892944},
#    {'text': 'how do i start a course',
#     'intent': 'start_course',
#     'predicted': 'start_course',
#     'confidence': 0.9414094090461731},
#    {'text': 'how can i start a course',
#     'intent': 'start_course',
#     'predicted': 'start_course',
#     'confidence': 0.9437834620475769},
#    {'text': 'how can i start my course',
#     'intent': 'start_course',
#     'predicted': 'start_course',
#     'confidence': 0.9486669301986694},
#    {'text': 'i want to start my course',
#     'intent': 'start_course',
#     'predicted': 'start_course',
#     'confidence': 0.947412371635437},
#    {'text': 'How do I register for a course',
#     'intent': 'course_register',
#     'predicted': 'course_register',
#     'confidence': 0.9637598395347595},
#    {'text': 'how i register a course',
#     'intent': 'course_register',
#     'predicted': 'course_register',
#     'confidence': 0.9588314890861511},
#    {'text': 'how can i register a course',
#     'intent': 'course_register',
#     'predicted': 'course_register',
#     'confidence': 0.9485006332397461},
#    {'text': 'course register',
#     'intent': 'course_register',
#     'predicted': 'course_register',
#     'confidence': 0.9530910849571228},
#    {'text': 'need to register course',
#     'intent': 'course_register',
#     'predicted': 'course_register',
#     'confidence': 0.9490877389907837},
#    {'text': 'Do you want to self register for a course?',
#     'intent': 'self_register',
#     'predicted': 'self_register',
#     'confidence': 0.9085114598274231},
#    {'text': 'Do you want to check the courses which you had already registered?',
#     'intent': 'already_reg',
#     'predicted': 'already_reg',
#     'confidence': 0.8961376547813416},
#    {'text': 'How do I search for a course',
#     'intent': 'course_search',
#     'predicted': 'course_search',
#     'confidence': 0.9667455554008484},
#    {'text': 'how can i search a course',
#     'intent': 'course_search',
#     'predicted': 'course_search',
#     'confidence': 0.9652645587921143},
#    {'text': 'search a course',
#     'intent': 'course_search',
#     'predicted': 'course_search',
#     'confidence': 0.9643069505691528},
#    {'text': 'search course',
#     'intent': 'course_search',
#     'predicted': 'course_search',
#     'confidence': 0.9633581638336182},
#    {'text': 'course search',
#     'intent': 'course_search',
#     'predicted': 'course_search',
#     'confidence': 0.9633581638336182},
#    {'text': 'i want to search a course',
#     'intent': 'course_search',
#     'predicted': 'course_search',
#     'confidence': 0.9629606604576111},
#    {'text': 'suggestion about search a course',
#     'intent': 'course_search',
#     'predicted': 'course_search',
#     'confidence': 0.9681246280670166},
#    {'text': 'Do you want to search for a specific course in LiveWire?',
#     'intent': 'specific_cours',
#     'predicted': 'specific_cours',
#     'confidence': 0.8940477967262268},
#    {'text': 'DO you want to perform a global search in LiveWire?',
#     'intent': 'global_search',
#     'predicted': 'global_search',
#     'confidence': 0.9466766119003296},
#    {'text': 'Where do I get my certificates?',
#     'intent': 'certificate',
#     'predicted': 'certificate',
#     'confidence': 0.9574097394943237},
#    {'text': 'where i get my all certificates',
#     'intent': 'certificate',
#     'predicted': 'certificate',
#     'confidence': 0.9560351371765137},
#    {'text': 'how can i get my certificates',
#     'intent': 'certificate',
#     'predicted': 'certificate',
#     'confidence': 0.9314907193183899},
#    {'text': 'my certificates',
#     'intent': 'certificate',
#     'predicted': 'certificate',
#     'confidence': 0.9576361775398254},
#    {'text': 'found my certificates',
#     'intent': 'certificate',
#     'predicted': 'certificate',
#     'confidence': 0.9582976698875427},
#    {'text': 'get my certificate',
#     'intent': 'certificate',
#     'predicted': 'certificate',
#     'confidence': 0.9595499634742737},
#    {'text': 'Do you want to view the list of certificates which you have gained?',
#     'intent': 'list_certificate',
#     'predicted': 'list_certificate',
#     'confidence': 0.9049007892608643},
#    {'text': 'I am not seeing any certificates under Learner Dashboard',
#     'intent': 'certificate_issue',
#     'predicted': 'certificate_issue',
#     'confidence': 0.9412329196929932},
#    {'text': 'certificates not found',
#     'intent': 'certificate_issue',
#     'predicted': 'certificate_issue',
#     'confidence': 0.9636216163635254},
#    {'text': 'my completed certificates not found',
#     'intent': 'certificate_issue',
#     'predicted': 'certificate_issue',
#     'confidence': 0.9510921239852905},
#    {'text': 'can not see my certificates',
#     'intent': 'certificate_issue',
#     'predicted': 'certificate_issue',
#     'confidence': 0.9420022964477539},
#    {'text': "can't see my certificates",
#     'intent': 'certificate_issue',
#     'predicted': 'certificate_issue',
#     'confidence': 0.949400007724762},
#    {'text': "learner dashboard i can't see my certificates",
#     'intent': 'certificate_issue',
#     'predicted': 'certificate_issue',
#     'confidence': 0.9361834526062012},
#    {'text': 'under learner dashboard , not seeing any certificates',
#     'intent': 'certificate_issue',
#     'predicted': 'certificate_issue',
#     'confidence': 0.9440416097640991},
#    {'text': 'Where do I find my learning transcripts',
#     'intent': 'transcript',
#     'predicted': 'transcript',
#     'confidence': 0.9133711457252502},
#    {'text': 'where i find my learning transcripts',
#     'intent': 'transcript',
#     'predicted': 'transcript',
#     'confidence': 0.9180198311805725},
#    {'text': 'could u pls find learning transcripts',
#     'intent': 'transcript',
#     'predicted': 'transcript',
#     'confidence': 0.9327642917633057},
#    {'text': 'find my learning transcripts',
#     'intent': 'transcript',
#     'predicted': 'transcript',
#     'confidence': 0.9337560534477234},
#    {'text': 'how i can find my learning transcripts',
#     'intent': 'transcript',
#     'predicted': 'transcript',
#     'confidence': 0.9254947900772095},
#    {'text': 'I am unable to complete the course',
#     'intent': 'course_complt_issue',
#     'predicted': 'course_complt_issue',
#     'confidence': 0.9635024666786194},
#    {'text': "i can't able to complete my course",
#     'intent': 'course_complt_issue',
# ...
#    {'text': 'search engine works',
#     'intent': 'course_engine',
#     'predicted': 'course_engine',
#     'confidence': 0.943064272403717},
#    {'text': 'Where do I find the recommended courses in Learning Catalog?',
#     'intent': 'Recommended_Course',
#     'predicted': 'Recommended_Course',
#     'confidence': 0.9532855153083801},
#    {'text': 'where i can find the recommended courses',
#     'intent': 'Recommended_Course',
#     'predicted': 'Recommended_Course',
#     'confidence': 0.9203019738197327},
#    {'text': 'the recommended courses in Learning Catalog',
#     'intent': 'Recommended_Course',
#     'predicted': 'Recommended_Course',
#     'confidence': 0.9594153165817261},
#    {'text': 'recommended courses',
#     'intent': 'Recommended_Course',
#     'predicted': 'Recommended_Course',
#     'confidence': 0.9531930685043335},
#    {'text': 'how can i find my recommended courses',
#     'intent': 'Recommended_Course',
#     'predicted': 'Recommended_Course',
#     'confidence': 0.9371194839477539},
#    {'text': 'how can i find my recommended course',
#     'intent': 'Recommended_Course',
#     'predicted': 'Recommended_Course',
#     'confidence': 0.9556669592857361},
#    {'text': 'I am unable to create a learning/course in the system.',
#     'intent': 'Course_Create',
#     'predicted': 'Course_Create',
#     'confidence': 0.9546549916267395},
#    {'text': 'can not create learning course in the system',
#     'intent': 'Course_Create',
#     'predicted': 'Course_Create',
#     'confidence': 0.9623774290084839},
#    {'text': "can't create learning courses",
#     'intent': 'Course_Create',
#     'predicted': 'Course_Create',
#     'confidence': 0.9683476686477661},
#    {'text': 'not able to create learning course in my login',
#     'intent': 'Course_Create',
#     'predicted': 'Course_Create',
#     'confidence': 0.9527456760406494},
#    {'text': 'I dont get any email notification on any of the learning assigned to me?',
#     'intent': 'Email_Trigger',
#     'predicted': 'Email_Trigger',
#     'confidence': 0.9553945660591125},
#    {'text': "i did't get email notification",
#     'intent': 'Email_Trigger',
#     'predicted': 'Email_Trigger',
#     'confidence': 0.9285964965820312},
#    {'text': 'i can not get my email notifications',
#     'intent': 'Email_Trigger',
#     'predicted': 'Email_Trigger',
#     'confidence': 0.9366106986999512},
#    {'text': 'did not get my email notification',
#     'intent': 'Email_Trigger',
#     'predicted': 'Email_Trigger',
#     'confidence': 0.9325916767120361},
#    {'text': 'not sending email notification',
#     'intent': 'Email_Trigger',
#     'predicted': 'Email_Trigger',
#     'confidence': 0.9120140671730042},
#    {'text': 'How can I request for a learning program ?',
#     'intent': 'Training_Request',
#     'predicted': 'Training_Request',
#     'confidence': 0.9648638367652893},
#    {'text': 'request for learning program',
#     'intent': 'Training_Request',
#     'predicted': 'Training_Request',
#     'confidence': 0.9698936939239502},
#    {'text': 'learning program request',
#     'intent': 'Training_Request',
#     'predicted': 'Training_Request',
#     'confidence': 0.9697757959365845},
#    {'text': 'shall i request learning program',
#     'intent': 'Training_Request',
#     'predicted': 'Training_Request',
#     'confidence': 0.9615850448608398},
#    {'text': 'Courses assigned to me does not match my Role.',
#     'intent': 'Enrolment',
#     'predicted': 'Enrolment',
#     'confidence': 0.9225507378578186},
#    {'text': 'courses does not match my role',
#     'intent': 'Enrolment',
#     'predicted': 'Enrolment',
#     'confidence': 0.9410154223442078},
#    {'text': 'Courses assigned to me did not match my Role',
#     'intent': 'Enrolment',
#     'predicted': 'Enrolment',
#     'confidence': 0.9215959310531616},
#    {'text': "Courses assigned to me did't match my Role",
#     'intent': 'Enrolment',
#     'predicted': 'Enrolment',
#     'confidence': 0.9205239415168762},
#    {'text': 'Where can I find the courses which I will need to complete by this month/today/week',
#     'intent': 'Course_Assignment',
#     'predicted': 'Course_Assignment',
#     'confidence': 0.9513627290725708},
#    {'text': 'my day was horrible',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9437573552131653},
#    {'text': 'I am sad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9617875814437866},
#    {'text': 'i am not fine',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9554710984230042},
#    {'text': 'not fine',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9547284841537476},
#    {'text': 'shamefull',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9653137922286987},
#    {'text': 'not good',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9582157731056213},
#    {'text': 'so bad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9545391201972961},
#    {'text': "don't well",
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9640979170799255},
#    {'text': 'very very bad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9568603038787842},
#    {'text': "I don't feel very well",
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9624341130256653},
#    {'text': 'I am disappointed',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9482597708702087},
#    {'text': 'super sad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.958034873008728},
#    {'text': "I'm so sad",
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9650863409042358},
#    {'text': 'sad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9577518701553345},
#    {'text': 'very sad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9606660008430481},
#    {'text': 'feeling bad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9510650038719177},
#    {'text': 'unhappy',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9496251940727234},
#    {'text': 'bad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9494159817695618},
#    {'text': 'very bad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9576861262321472},
#    {'text': 'awful',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9612892270088196},
#    {'text': 'terrible',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.968684196472168},
#    {'text': 'not so good',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9605628252029419},
#    {'text': 'not very good',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.9579088091850281},
#    {'text': 'extremly sad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.95512855052948},
#    {'text': 'so sad',
#     'intent': 'mood_unhappy',
#     'predicted': 'mood_unhappy',
#     'confidence': 0.958486795425415},
#    {'text': 'Looking for course about java',
#     'intent': 'java_search',
#     'predicted': 'java_search',
#     'confidence': 0.9509145617485046},
#    {'text': 'Looking for java.',
#     'intent': 'java_search',
#     'predicted': 'java_search',
#     'confidence': 0.9474915266036987},
#    {'text': 'Any interesting course java technology you can recommend?',
#     'intent': 'java_search',
#     'predicted': 'java_search',
#     'confidence': 0.9351792335510254},
#    {'text': 'Would like to read some course about java.',
#     'intent': 'java_search',
#     'predicted': 'java_search',
#     'confidence': 0.9386442303657532},
#    {'text': 'Any recommendataions for java course to read?',
#     'intent': 'java_search',
#     'predicted': 'java_search',
#     'confidence': 0.9429687857627869},
#    {'text': 'Looking for papers about chatbots',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9445235729217529},
#    {'text': 'Please suggest some interesting papers to read',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9339396953582764},
#    {'text': 'Looking for some new papers about machine learning',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9459437727928162},
#    {'text': 'Any recommendataions for statistics papers to read?',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9510753154754639},
#    {'text': 'I have some spare time and would like to read some mathematics papers.',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9451775550842285},
#    {'text': 'Looking for papers to read',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9576238989830017},
#    {'text': 'Do you have new papers to recommend?',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9350652098655701},
#    {'text': 'Would like to read some papers about physics.',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.948077380657196},
#    {'text': 'Please recommend some interesting papers about astronomy.',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9521368145942688},
#    {'text': 'Looking for econometrics papers.',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9533677101135254},
#    {'text': 'Looking for papers in artificial intelligence',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9122519493103027},
#    {'text': 'Please share some papers to read',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9324114322662354},
#    {'text': 'Looking for Physics to read.',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9408046007156372},
#    {'text': 'Can you recommend me Mathematics?',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9322787523269653},
#    {'text': 'Any interesting papers statistics you can recommend?',
#     'intent': 'paper_search',
#     'predicted': 'paper_search',
#     'confidence': 0.9505992531776428},
#    {'text': 'i want to enroll',
#     'intent': 'enroll',
#     'predicted': 'enroll',
#     'confidence': 0.9302136898040771},
#    {'text': 'need to enroll id',
#     'intent': 'enroll',
#     'predicted': 'enroll',
#     'confidence': 0.9225442409515381},
#    {'text': 'how to i enroll id enrolla course',
#     'intent': 'enroll',
#     'predicted': 'enroll',
#     'confidence': 0.9170361757278442},
#    {'text': 'about statistics',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9202223420143127},
#    {'text': 'maybe mathematics',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9398014545440674},
#    {'text': 'about geography',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9298378825187683},
#    {'text': 'for machine learning',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9096516966819763},
#    {'text': 'about differentiation',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9298784732818604},
#    {'text': 'maybe about calculus',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.953241765499115}],
#   'report': '                          precision    recall  f1-score   support\n\nAsssessmet_Page_Activity       1.00      1.00      1.00        12\n       Course_Assignment       1.00      1.00      1.00         1\n           Course_Create       1.00      1.00      1.00         4\n         Course_Creation       1.00      1.00      1.00        14\n     Course_Launch_Issue       1.00      1.00      1.00        17\n      Course_Next_Button       1.00      1.00      1.00        17\n     Course_Prerequisite       1.00      1.00      1.00         5\n           Email_Trigger       1.00      1.00      1.00         5\n               Enrolment       1.00      1.00      1.00         4\n                LIVEWIRE       1.00      1.00      1.00        11\n      Recommended_Course       1.00      1.00      1.00         6\n        Training_Request       1.00      1.00      1.00         4\n        User_Login_Issue       1.00      1.00      1.00        20\n          acces_livewire       1.00      1.00      1.00        19\n               allcourse       1.00      1.00      1.00         6\n             already_reg       1.00      1.00      1.00         1\n            app_LiveWire       1.00      1.00      1.00         4\n                  botage       1.00      1.00      1.00        14\n             botlanguage       1.00      1.00      1.00        10\n                 botname       1.00      1.00      1.00         8\n             certificate       1.00      1.00      1.00         6\n       certificate_issue       1.00      1.00      1.00         7\n           comp_training       1.00      1.00      1.00         4\n     course_complt_issue       1.00      1.00      1.00         3\n           course_engine       1.00      1.00      1.00         5\n         course_register       1.00      1.00      1.00         5\n           course_search       1.00      1.00      1.00         7\n                  enroll       1.00      1.00      1.00         3\n           enroll_course       1.00      1.00      1.00         5\n           global_search       1.00      1.00      1.00         1\n                 goodbye       1.00      0.91      0.95        11\n                   greet       0.93      1.00      0.96        13\n                helpuser       1.00      1.00      1.00         8\n                  inform       1.00      1.00      1.00         6\n       issue_comp_course       1.00      1.00      1.00         1\n             java_search       1.00      1.00      1.00         5\n           launch_course       1.00      1.00      1.00         4\n        list_certificate       1.00      1.00      1.00         1\n          livewire_cours       1.00      1.00      1.00         5\n             mood_affirm       1.00      1.00      1.00         5\n               mood_deny       1.00      1.00      1.00         6\n              mood_great       1.00      1.00      1.00        25\n            mood_unhappy       1.00      1.00      1.00        25\n        my_enroll_course       1.00      1.00      1.00         5\n            paper_search       1.00      1.00      1.00        15\n           self_register       1.00      1.00      1.00         1\n        softskill_course       1.00      1.00      1.00         3\n          specific_cours       1.00      1.00      1.00         1\n            start_course       1.00      1.00      1.00         4\n        technical_course       1.00      1.00      1.00         3\n              transcript       1.00      1.00      1.00         5\n\n               micro avg       1.00      1.00      1.00       380\n               macro avg       1.00      1.00      1.00       380\n            weighted avg       1.00      1.00      1.00       380\n',
#   'precision': 0.9975563909774435,
#   'f1_score': 0.9973544973544972,
#   'accuracy': 0.9973684210526316},
#  'entity_evaluation': {'CRFEntityExtractor': {'report': '              precision    recall  f1-score   support\n\n enroll_type       1.00      0.40      0.57         5\n   java_type       1.00      1.00      1.00         6\n   no_entity       1.00      1.00      1.00      1700\n  paper_type       1.00      1.00      1.00        20\n\n   micro avg       1.00      1.00      1.00      1731\n   macro avg       1.00      0.85      0.89      1731\nweighted avg       1.00      1.00      1.00      1731\n',
#    'precision': 0.9982699507750111,
#    'f1_score': 0.9978962826226251,
#    'accuracy': 0.9982668977469671}}}

# %% [markdown]
# ## 2. Teaching the bot to respond using Rasa Core
# ### 1. Defining a Domain

# %%
domain_yml = """
intents:
- greet
- LIVEWIRE
- Course_Launch_Issue
- User_Login_Issue
- Course_Next_Button
- Course_Creation
- Asssessmet_Page_Activity
- acces_livewire
- livewire_cours
- app_LiveWire
- goodbye
- mood_affirm
- mood_deny
- mood_great
- botname
- helpuser
- botlanguage
- botage
- allcourse
- my_enroll_course
- technical_course
- comp_training
- softskill_course
- launch_course
- enroll_course
- start_course
- course_register
- self_register
- already_reg
- course_search
- specific_cours
- global_search
- certificate
- list_certificate
- certificate_issue
- transcript
- course_complt_issue
- issue_comp_course
- Course_Prerequisite
- course_engine
- Recommended_Course
- Course_Create
- Email_Trigger
- Training_Request
- Enrolment
- Course_Assignment 
- mood_unhappy
- java_search
- paper_search
- enroll
- inform

slots:
  paper_type:
    type: text
  enroll_type:
    type: text
  link:
    type: text
  authors:
    type: text
        
entities:
- paper_type
- enroll_type

actions:
- utter_greet
- utter_livewire
- utter_course_launch_issue
- utter_user_login_issue
- utter_course_next_button
- utter_course_creation
- utter_assesment_page_activity
- utter_access_livewire
- utter_livewire_cours
- utter_app_livewire
- utter_did_that_help
- utter_happy
- utter_goodbye
- utter_unclear
- utter_botname
- utter_helpuser
- utter_botlang
- utter_botage
- utter_all_course
- utter_my_enroll_Course
- utter_technical_Course
- utter_completed_Course
- utter_softskill_course
- utter_launch_course
- utter_enroll_course
- utter_start_course
- utter_course_register
- utter_self_register
- utter_already_reg
- utter_course_search
- utter_specific_cours
- utter_global_search
- utter_certificate
- utter_list_certificate
- utter_certificate_issue
- utter_transcript
- utter_course_complt_issue
- utter_issue_comp_course
- utter_Course_Prerequisite
- utter_course_engine
- utter_Recommended_Course
- utter_Course_Create
- utter_Email_Trigger
- utter_Training_Request
- utter_Enrolment
- utter_Course_Assignment 
- utter_ask_picture
- utter_default
- action_paper_search
- action_enroll

templates:
  utter_greet:
  - text: "Hey! How are you?"
    buttons:
    - title: "great"
      payload: "great"
    - title: "super sad"
      payload: "super sad"
  
  utter_livewire:
  - text: "Sify livewire is a e-Learning application for managing training and educational records and software for distributing courses over the Internet with features for online collaboration. <ctag>Do you want to access Livewire?</ctag>"
  
  utter_user_login_issue:
  - text: "Sify Livewire is completely integrated with your (Company) AD system. In order to get logged into livewire portal please use your AD credentials. For most of the cases your AD credentials is nothing but your corporate email id and your system password (System which is provided by company). Incase issue persists please reach out to your (company) IT team."
  
  utter_course_next_button:
  - text: "We strongly recommend you view all the information of current slide/page or else next button may not enabled for you. You should not skip any contents of the slide."
  
  utter_course_creation:
  - text: "Forwarded to project team and resolved"
  
  
  utter_assesment_page_activity:
  - text: "Assessments can consists of multiple questions with each having more than one answer options. Options may be single choice demoted by radio buttons or multiple choices denoted by check boxes.You can select only one option if you see raido buttons and multiple options if there are check boxes"
  
  
  utter_course_launch_issue:
  - text: "If you are trying the launch a course or an asssessment and see an exception page or a page not found error, please clear your browser cache and retry. Useful link to watch how to clear your browser cache. https://www.youtube.com/results?search_query=how+to+clear+browser+cache "
  
  utter_access_livewire:
  - text: "Livewire can be access via  http://livewire.com/ "
  
  utter_livewire_cours:
  - text: "Kindly click on the Course Menu - Course List to access the courses"
  
  utter_app_livewire:
  - text: "Application of livewire is  ...   "
  
  utter_did_that_help:
  - text: "Did that help you?"

  utter_unclear:
  - text: "I am not sure what you are aiming for."
  
  utter_happy:
  - text: "Great ! carry on...."

  utter_goodbye:
  - text: "Bye "
  
  utter_botname:
  - text: "My name is SIFYBOT , and i am a chatbot "
  
  utter_helpuser:
  - text: "sure i makes you feel good "
  
  utter_botlang:
  - text: "I can understand Only English "
  
  utter_botage:
  - text: "Age has no meaning , because i am Virtual . i was created in september-2019. But i am probabaly already smater than you "
  
  utter_all_course:
  - text: "All course..."
  
  utter_my_enroll_Course:
  - text: "My enroll course"
  
  utter_technical_Course:
  - text: "technical course.."
  
  utter_completed_Course:
  - text: "completed course"
  
  utter_softskill_course:
  - text: "softskill course"
  
  utter_launch_course:
  - text: "launch course"
  
  utter_enroll_course:
  - text: "enroll course"
  
  utter_start_course:
  - text: "start course"
  
  utter_course_register:
  - text: "<ctag>Do you want to self register for a course?</ctag>, <ctag>Do you want to check the courses which you had already registered?</ctag> "
  
  utter_self_register:
  - text: "Kindly get into All Courses tab available under Course List and click on the details button upon which you will find enroll button . Click on Enrol button to register for the course."
 
  utter_already_reg:
  - text: "Kindly click on the Enroled Course Menu available under Course List to access the list of the courses which you have been enrolled/registered for."
  
  utter_course_search:
  - text: "<ctag>Do you want to search for a specific course in LiveWire?</ctag>, <ctag>DO you want to perform a global search in LiveWire?</ctag>"
 
  utter_specific_cours:
  - text: "Kindly click on the Course Menu- Course List to access courses. Upon which you will have search field, where in you can provide the course title and click on search icon."
  
  utter_global_search:
  - text: "Kindly provide the search value in the menu line and click on the search icon. This will share the search results globally."
  
  utter_certificate:
  - text: "<ctag>Do you want to view the list of certificates which you have gained?</ctag>"
  
  utter_list_certificate:
  - text: "Kindly click on the Report Menu under which you will have learner dashboard which will enable to get the list of certificates gained by the user"
  
  utter_certificate_issue:
  - text: "Kindly check with your LMS administrator if you have any certificates tagged to Completed Courses."
  
  utter_transcript:
  - text: "Kindly click on the Course Menu - Course List to access the list of completed courses. You will be finding the learning transcripts in Completed Courses."
  
  utter_course_complt_issue:
  - text: "Kindly complete all learning modules tagged to the course for the course to be completed."
  
  utter_issue_comp_course:
  - text: "Kindly reach out to LMS administrator to check for the completion of the course."
  
  
  utter_Course_Prerequisite:
  - text: "If a course that has retraining on it, as well as a prerequisite: the prerequiste will not be reassigned when the retraining starts. This is because the prerequisite will have already been met the first time the user took the course."
  
  utter_course_engine:
  - text: "You will be able to search for any course name searches with the course search engine.If you still have any issues in identifying the course,please reach out to LMS Administrator."
 
  utter_Recommended_Course:
  - text: "You will find your recommended courses under Course List --> Recommended Course tab. If you still have any issues in identifying the recommended tab, please reach out to LMS Support."
 
  utter_Course_Create:
  - text: "Create of courses is a permission which LMS Administrator will need to assign it to your userid. Kindly check with LMS Administrator or reach out to our LMS Support on this assistance."
 
  utter_Email_Trigger:
  - text: "Email notifications will need to be configured in the system for the trigger to the learners. Kindly reach out to LMS Administrator or LMS Support who can assist you."
  
  utter_Training_Request:
  - text: "Kindly reach out to LMS administrator or click on the Contact button to request for your learning program."
 
  utter_Enrolment:
  - text: "Kindly reach out to LMS Administrator on the learning assignments."
  
  utter_Course_Assignment:
  - text: "Kindly click on the Courses --> Calendar, where in you will find a day /week/month view of the courses assigned to you."
  
  utter_ask_picture:
  - text: "To cheer you up, Don't loose your hope , all is well "
  
  utter_default:
  - text: "I am sorry, I am yet to learn about this. you may ask me something about  <ctag>Livewire</ctag> instead ."
"""

# %store domain_yml > domain.yml
# Out:
# Writing 'domain_yml' (str) to file 'domain.yml'.

# %% [markdown]
# ## 2. Writing Stories

# %%
stories_md = """
## happy path               <!-- name of the story - just for debugging -->
* greet              
  - utter_greet
* mood_great               <!-- user utterance, in format intent[entities] -->
  - utter_happy
* mood_affirm
  - utter_happy
* mood_affirm
  - utter_goodbye
  
## sad path 1               <!-- this is already the start of the next story -->
* greet
  - utter_greet             <!-- action the bot should execute -->
* mood_unhappy
  - utter_ask_picture
* mood_affirm
  - utter_happy

## sad path 2
* greet
  - utter_greet
* mood_unhappy
  - utter_ask_picture
* mood_deny
  - utter_goodbye
  
## sad path 3
* greet
  - utter_greet
* mood_affirm
  - utter_happy
  
## strange user
* mood_affirm
  - utter_happy
* mood_affirm
  - utter_unclear

## course launch issue
* Course_Launch_Issue
  - utter_course_launch_issue
* Course_Creation
  - utter_course_creation
* User_Login_Issue
  - utter_user_login_issue

## user login issue
* User_Login_Issue
  - utter_user_login_issue

## course next button
* Course_Next_Button
  - utter_course_next_button
* Asssessmet_Page_Activity
  - utter_assesment_page_activity

## course creation
* Course_Creation
  - utter_course_creation

## assesment page activity 
* Asssessmet_Page_Activity
  - utter_assesment_page_activity
  
## Live wire
* LIVEWIRE
  - utter_livewire
  
## access livewire
*acces_livewire
  - utter_access_livewire
  
## livewire_cours
*livewire_cours
  -utter_livewire_cours
  
## application Livewire
* app_LiveWire
  - utter_app_livewire

## say goodbye
* goodbye
  - utter_goodbye
  
##asking bot name
* botname
  - utter_botname

## user helping
* helpuser
  - utter_helpuser

## bot language
* botlanguage
  - utter_botlang

## age of bot
*botage
  - utter_botage

## all course
* allcourse
 - utter_all_course

## my enroll course
* my_enroll_course
 - utter_my_enroll_Course

## technical course
* technical_course
 - utter_technical_Course

## my completed course
* comp_training
 - utter_completed_Course

## softskill course
* softskill_course
 - utter_softskill_course

## launch course
* launch_course
 - utter_launch_course

## enroll course
* enroll_course
 - utter_enroll_course

## start course
* start_course
 - utter_start_course
 
## course register-----------------------------------------

* course_register
  - utter_course_register
* self_register
  - utter_self_register
* already_reg
  - utter_already_reg
  
## self_register
* self_register
  - utter_self_register
  
## already_reg
* already_reg
  - utter_already_reg
  
## course search

* course_search
  - utter_course_search
* specific_cours
  - utter_specific_cours
* global_search
  - utter_global_search

##specific course
* specific_cours
  - utter_specific_cours

##global search
* global_search
  - utter_global_search

## certificate

* certificate
  - utter_certificate
* list_certificate
  - utter_list_certificate

## list_certi
* list_certificate
  - utter_list_certificate

## certificate issue
* certificate_issue
  - utter_certificate_issue

## Transcript
* transcript
  - utter_transcript
  
## mood happy 
* mood_affirm
  - utter_happy

## course complete issue 
* course_complt_issue
  - utter_course_complt_issue

## issue complete course 
* issue_comp_course
  - utter_issue_comp_course
  
## Course_Prerequisite
* Course_Prerequisite
  - utter_Course_Prerequisite

## course_engine
* course_engine
  - utter_course_engine  

## Recommended_Course 
* Recommended_Course
  - utter_Recommended_Course
  
## Course_Create
* Course_Create
  - utter_Course_Create 
  
## Email_Trigger 
* Email_Trigger
  - utter_Email_Trigger
  
## Training_Request
* Training_Request
  - utter_Training_Request  
  
## Enrolment
* Enrolment
  - utter_Enrolment
  
  
## Course_Assignment 
* Course_Assignment
  - utter_Course_Assignment
  
  
## Suggestion path 9-----------------------------------------
* greet
  - utter_greet
* paper_search{"paper_type":"physics"}
  - action_paper_search
  - utter_happy
* mood_affirm
  - utter_happy
  
## enroll course  path
* greet
  - utter_greet 
* enroll{"enroll_type":"id enroll"}
  - action_enroll
  - utter_happy
* mood_affirm
  - utter_happy

## fallback
  - utter_unclear

"""

# %store stories_md > stories.md
# Out:
# Writing 'stories_md' (str) to file 'stories.md'.

# %%
custom_action = """
from rasa_core_sdk import Action
from rasa_core_sdk.events import SlotSet

import requests

class ApiAction(Action):
    def name(self):
        return "action_enroll"

    def run(self, dispatcher, tracker, domain):
    #def run(self):
        enroll_type = tracker.get_slot('enroll_type')
        url = "http://lwawstest1.sifylivewire.com/api/enrolcourse"
        headers = {
    'Content-Type': "application/x-www-form-urlencoded",
    'Authorization': "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6ImIwNmZkYWJiNDlmYTMwMTFhMzZlYmM0YTRhM2Q1ZGZkOWVlZjQ4OWIzNmYxOTIxZjNmOTY2OTlmMDYyYTRhYWFiODExNGQ3N2ZkNmI0NTBmIn0.eyJhdWQiOiIzIiwianRpIjoiYjA2ZmRhYmI0OWZhMzAxMWEzNmViYzRhNGEzZDVkZmQ5ZWVmNDg5YjM2ZjE5MjFmM2Y5NjY5OWYwNjJhNGFhYWI4MTE0ZDc3ZmQ2YjQ1MGYiLCJpYXQiOjE1NjkzODgwNzEsIm5iZiI6MTU2OTM4ODA3MSwiZXhwIjoxNTcwNjg0MDcxLCJzdWIiOiIiLCJzY29wZXMiOltdfQ.I0MUa8B21zx-fo-aeOcuYzGMxG8DFwX3YW-cwRIDXkFCQa615Kxxa_g9ILb5cPWvVg15YplzaZr3z9euwG6Y0SbOdiZUVH9vbK9n4I6NECQmTQdMfkddJ5CyBgHmhrUdnuJHdpSAWSWGQy8RsCS543re42sI9WcA6-WOTIA1iA7gpIiM1vF00Vdlvo0WcKekgLl1cs6cOgAY0a62nJn2iiT5me-LfTcTZHO5t62_BbYldXTssNyZmDqutaQHBArW-M016YDvk6tnaKVvZnIC3HvAMUWPZQgBiOre5upvFXeF6Dklh9CWn17kJELLz6NtMsdmjpvq44UqyRWVOwH4MyPPUQjN3ycf-w6xzjHW7zzkab4d5qX0ITF1_sdcIc5QBZYVu0-RYDvezsIqmlxi_CQfpfgrYEp-tzdzhrbKRAn1PSN5yc3a-_RGTLRe7jiCklqbPQcYhEZkXlUgsw_1B6hs58SM6Ixd1hOraiMkt01AdAkk4iE5dzxKBem6eaWvJeZiZ7e-TJjddL-VBwwjxG1R20RBtPMRVNAlt3NpqCOnzomL86cVmKMKOMI_CO6urlKnp8xRCSYap96NcBJrLOme_HyMP0IFZvGlkDNQNTHaULVi3OeOS-zRkVUQgGpFL6HmjhC_lHIs6AvxVKenLCojkFYVRaT5xZ-uzq-wa4c",
    'saltkey': "ZllZS1Vhd2pIcmlKS1IzcURSS0tOZE0zQzkwQWVyU3IxbXN1MUpHaw==",
    'User-Agent': "PostmanRuntime/7.17.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Postman-Token': "fd8d64b0-7229-4b61-9b6f-6201ab7047b9,5e6c8a9d-90a1-442d-b104-f99d86ab6e2c",
    'Host': "lwawstest1.sifylivewire.com",
    'Accept-Encoding': "gzip, deflate",
    'Content-Length': "112",
    'Cookie': "Tenantname=lwawstest1",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }
        payload = "usls=%7B%22user_id%22%3A%22superadmin%40mail.com%22%2C%22course_delivery_id%22%3A%221896%22%2C%20%22course_id%22%3A%222234%22%7D"
        #payload= {"user_id":"superadmin@mail.com","course_delivery_id":"1568", "course_id":"1790"}
        response = requests.request("POST", url, data=payload,headers=headers)
        #print(response.text)
        status=response.json()
        stat=status['data']
        stats=stat['error']
        dispatcher.utter_message("Your status is  {}".format(stats))
        #return [SlotSet("link",link), SlotSet("authors",authors)]
""" 
# %store custom_action > actions.py
# Out:
# Writing 'custom_action' (str) to file 'actions.py'.

# %%
from IPython.display import Image
from rasa_core.agent import Agent

agent = Agent('domain.yml')
agent.visualize("stories.md", "story_graph.png", max_history=2)
Image(filename="story_graph.png")
# Out:
# INFO:apscheduler.scheduler:Scheduler started
# Processed Story Blocks: 100%|██████████████████████████████████████████| 28/28 [00:00<00:00, 1080.96it/s, # trackers=1]

# %%
policiess=policy_config.load('policy.yml')
agent=Agent('domain.yml',policies=policiess)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-4ceb5f906a85> in <module>
#       1 policiess=policy_config.load('policy.yml')
#       2 agent=Agent('domain.yml',policies=policiess)
# ----> 3 training_
#
# NameError: name 'training_' is not defined

# %% [markdown]
# ## Training a Dialogue Model

# %%
from rasa_core.policies import FallbackPolicy, KerasPolicy, MemoizationPolicy 
from rasa_core.agent import Agent

from rasa_core import config as policy_config


# this will catch predictions the model isn't very certain about
# there is a threshold for the NLU predictions as well as the action predictions
fallback = FallbackPolicy(fallback_action_name="utter_unclear",
                          core_threshold=0.2,
                          nlu_threshold=0.26)

#agent = Agent('domain.yml', policies=[MemoizationPolicy(), KerasPolicy(), fallback])
policiess = policy_config.load("policy.yml")
agent = Agent("domain.yml", policies=policiess)

# loading our neatly defined training dialogues
training_data = agent.load_data('stories.md') 

agent.train(
    training_data
)
''' agent.train(
    training_data,
    validation_split=0.2,
    epochs=200
)'''

agent.persist('models/dialogue')
# Out:
# Processed Story Blocks: 100%|██████████████████████████████████████████| 51/51 [00:00<00:00, 1042.64it/s, # trackers=1]
# Processed Story Blocks: 100%|██████████████████████████████████████████| 51/51 [00:00<00:00, 325.71it/s, # trackers=20]
# Processed Story Blocks: 100%|██████████████████████████████████████████| 51/51 [00:00<00:00, 288.91it/s, # trackers=20]
# Processed Story Blocks: 100%|███████████████████████████████████████████| 51/51 [00:00<00:00, 56.96it/s, # trackers=16]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (None, 3, 115)            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                18944
# _________________________________________________________________
# dense (Dense)                (None, 58)                1914
# _________________________________________________________________
# activation (Activation)      (None, 58)                0
# =================================================================
# Total params: 20,858
# Trainable params: 20,858
# Non-trainable params: 0
# _________________________________________________________________
# INFO:rasa_core.policies.keras_policy:Fitting model with 575 total samples and a validation split of 0.1
# Epoch 1/200
# 575/575 [==============================] - ETA: 9s - loss: 4.0766 - acc: 0.0000e+0 - ETA: 0s - loss: 4.0225 - acc: 0.1699    - 1s 1ms/sample - loss: 4.0177 - acc: 0.1930
# Epoch 2/200
# 575/575 [==============================] - ETA: 0s - loss: 3.9369 - acc: 0.593 - ETA: 0s - loss: 3.9031 - acc: 0.494 - 0s 104us/sample - loss: 3.8993 - acc: 0.4939
# Epoch 3/200
# 575/575 [==============================] - ETA: 0s - loss: 3.7714 - acc: 0.625 - 0s 88us/sample - loss: 3.7109 - acc: 0.5043
# Epoch 200/200
# 575/575 [==============================] - ETA: 0s - loss: 0.1335 - acc: 1.000 - ETA: 0s - loss: 0.2029 - acc: 0.961 - 0s 106us/sample - loss: 0.2049 - acc: 0.9635
# INFO:rasa_core.policies.keras_policy:Done fitting keras policy model
# Processed actions: 132it [00:00, 1408.01it/s, # examples=130]
# INFO:rasa_core.agent:Model directory models/dialogue exists and contains old model files. All files will be overwritten.
# INFO:rasa_core.agent:Persisted model to 'C:\Users\015864\Sify_Chat_bot_livewire1.1 (Custom API action)\models\dialogue'

# %%
#!python -m rasa_sdk.endpoint --actions actions
#!python -m rasa_sdk --actions actions
# Out:
# 2019-09-26 10:18:26 INFO     rasa_sdk.endpoint  - Starting action endpoint server...
# E:\ANACONDA\lib\site-packages\rasa_core_sdk\__init__.py:12: UserWarning: The 'rasa_core_sdk' package has been renamed. You should change your imports to use 'rasa_sdk' instead.
#   UserWarning,
# 2019-09-26 10:18:26 INFO     rasa_sdk.executor  - Registered function for 'action_paper_search'.
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "E:\ANACONDA\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "E:\ANACONDA\lib\site-packages\rasa_sdk\endpoint.py", line 140, in <module>
#     rasa_sdk.__main__.main()
#   File "E:\ANACONDA\lib\site-packages\rasa_sdk\__main__.py", line 26, in main
#     main_from_args(cmdline_args)
#   File "E:\ANACONDA\lib\site-packages\rasa_sdk\__main__.py", line 18, in main_from_args
#     run(args.actions, args.port, args.cors)
#   File "E:\ANACONDA\lib\site-packages\rasa_sdk\endpoint.py", line 131, in run
#     http_server.start()
#   File "E:\ANACONDA\lib\site-packages\gevent\baseserver.py", line 305, in start
#     self.init_socket()
#   File "E:\ANACONDA\lib\site-packages\gevent\pywsgi.py", line 1490, in init_socket
#     StreamServer.init_socket(self)
#   File "E:\ANACONDA\lib\site-packages\gevent\server.py", line 146, in init_socket
#     self.socket = self.get_listener(self.address, self.backlog, self.family)
#   File "E:\ANACONDA\lib\site-packages\gevent\server.py", line 157, in get_listener
#     return _tcp_listener(address, backlog=backlog, reuse_addr=cls.reuse_addr, family=family)
#   File "E:\ANACONDA\lib\site-packages\gevent\server.py", line 256, in _tcp_listener
#     sock.bind(address)
# OSError: [WinError 10048] Only one usage of each socket address (protocol/network address/port) is normally permitted: ('0.0.0.0', 5055)

# %%
import IPython
from IPython.display import clear_output
from rasa_core.agent import Agent
from rasa_core.interpreter import NaturalLanguageInterpreter
from rasa_core.utils import EndpointConfig
#from rasa_mongo_tracker_store.store import MongoTrackerStore
from rasa_core.tracker_store import MongoTrackerStore
import time  
messages = ["Hi! you can chat in this window. Type 'stop' to end the conversation."]
interpreter = NaturalLanguageInterpreter.create('models/nlu/default/current')
endpoint = EndpointConfig('http://localhost:5055/webhook')
db= MongoTrackerStore( None,host='mongodb://localhost:27017', db='chat_db',collection='logcol',event_broker=None)
agent = Agent.load('models/dialogue', interpreter=interpreter,tracker_store=db, action_endpoint = endpoint)
#print(agent)
#time.sleep(1)
print("********** SIFY Bot is ready to talk! Type your messages here or send 'stop' ******* ")
while True:
    a = input("user : ")
    #logger.info(a) 
    if a == 'stop':
        print("Thank you Welcome again .! ")
        break
    responses = agent.handle_text(a)
    for response in responses:
        print("Bot :",response["text"])
        print()

# looking for paper about Physics
# Out:
# INFO:tensorflow:Restoring parameters from models/nlu/default/current\component_6_EmbeddingIntentClassifier.ckpt
# ********** SIFY Bot is ready to talk! Type your messages here or send 'stop' *******
# user : hey
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# WARNING:rasa_core.domain:Failed to use action 'utter_pal' in history. Please make sure all actions are listed in the domains action list. If you recently removed an action, don't worry about this warning. It should stop appearing after a while.
# Bot : Hey! How are you?
#
# user : stop
# Thank you Welcome again .!
